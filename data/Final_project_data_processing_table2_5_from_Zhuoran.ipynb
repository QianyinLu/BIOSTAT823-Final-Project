# %%
import numpy as np
import pandas as pd
import requests

# %%
! pip install sodapy

# %%
import pandas as pd
from sodapy import Socrata

# %%
client = Socrata("data.cdc.gov", None)
results = client.get("9mfq-cb36", limit=20000)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
df1 = pd.DataFrame.from_records(results)

# %%
df1
# Out:
#              submission_date state tot_cases new_case tot_death new_death  \
# 0    2020-01-22T00:00:00.000    CO         0        0         0         0
# 1    2020-01-23T00:00:00.000    CO         0      0.0         0       0.0
# 2    2020-01-24T00:00:00.000    CO         0      0.0         0       0.0
# 3    2020-01-25T00:00:00.000    CO         0      0.0         0       0.0
# 4    2020-01-26T00:00:00.000    CO         0      0.0         0       0.0
# ..                       ...   ...       ...      ...       ...       ...
# 995  2020-07-31T00:00:00.000    SC     89016   1444.0      1712      45.0
# 996  2020-08-01T00:00:00.000    SC     90599   1583.0      1751      39.0
# 997  2020-08-02T00:00:00.000    SC     91788   1189.0      1777      26.0
# 998  2020-08-03T00:00:00.000    SC     92951   1163.0      1793      16.0
# 999  2020-08-04T00:00:00.000    SC     94190   1239.0      1847      54.0
#
#                   created_at consent_cases consent_deaths conf_cases  \
# ...

# %%
# ?client.get

# %%
n=10000

# %%
results2 = client.get("vbim-akqf", limit=n)

# %%
df2 = pd.DataFrame.from_records(results2)
df2
# Out:
#                 cdc_report_dt              pos_spec_dt  \
# 0     2020-03-22T00:00:00.000  2020-03-15T00:00:00.000
# 1     2020-03-23T00:00:00.000  2020-03-15T00:00:00.000
# 2     2020-03-15T00:00:00.000  2020-03-15T00:00:00.000
# 3     2020-03-15T00:00:00.000  2020-03-15T00:00:00.000
# 4     2020-03-15T00:00:00.000  2020-03-15T00:00:00.000
# ...                       ...                      ...
# 9995  2020-08-15T00:00:00.000  2020-08-13T00:00:00.000
# 9996  2020-08-18T00:00:00.000  2020-08-13T00:00:00.000
# 9997  2020-08-13T00:00:00.000  2020-08-13T00:00:00.000
# 9998  2020-08-20T00:00:00.000  2020-08-13T00:00:00.000
# 9999  2020-08-24T00:00:00.000  2020-08-13T00:00:00.000
#
#                      onset_dt             current_status     sex  \
# 0     2020-03-11T00:00:00.000  Laboratory-confirmed case  Female
# 1                         NaN  Laboratory-confirmed case  Female
# 2                         NaN  Laboratory-confirmed case  Female
# ...

# %%
# Out:
# '2020-09-15T00:00:00.000'
